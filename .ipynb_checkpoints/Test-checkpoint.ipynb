# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import  risk_models
from pypfopt import expected_returns
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices
from pypfopt import plotting

# %%
#Defining symbols in our portfolio.
tickers = ["TSLA", "BIDU", "NVDA", "AAL", "PYPL", "UBER", "DIS", "DHR", "PANW","FWONK","MCL.CN","FI"]

# %%
portfolio_creation_date = "2019-05-10"
portfolio_rebalance_date = "2023-11-07"

# %%
#Downloading 10 years of data from yahoo finance.
stock_data = yf.download(tickers, period="5y")
# Out:
# [*********************100%%**********************]  12 of 12 completed

# %%
prices = pd.DataFrame(stock_data["Adj Close"].dropna(how="all"))
#prices.set_index("Date", inplace = True)
prices.head(10)
# Out:
#                   AAL        BIDU        DHR         DIS         FI  \
# Date
# 2018-11-09  35.643646  183.750000  90.401436  115.678024  80.239998
# 2018-11-12  36.273460  180.429993  87.942017  114.403603  78.589996
# 2018-11-13  37.178822  183.339996  87.024055  114.550652  77.660004
# 2018-11-14  37.503571  185.059998  87.240555  114.815346  77.750000
# 2018-11-15  37.218182  188.410004  88.028603  114.805542  79.709999
# 2018-11-16  36.165211  186.949997  89.370903  113.903648  80.279999
# 2018-11-19  35.250011  183.089996  87.725487  113.148788  78.559998
# 2018-11-20  35.023670  177.479996  88.305740  109.668648  76.080002
# 2018-11-21  35.732212  183.949997  89.145752  110.805824  76.839996
# 2018-11-22        NaN         NaN        NaN         NaN        NaN
#
#                 FWONK  MCL.CN       NVDA       PANW       PYPL       TSLA  \
# Date
# 2018-11-09  32.114059   0.030  50.971600  61.029999  86.760002  23.367332
# 2018-11-12  31.229105   0.025  46.974064  59.116669  83.779999  22.085333
# 2018-11-13  31.809242   0.025  49.395390  58.933334  83.779999  22.582001
# 2018-11-14  31.317600   0.025  48.869980  58.926666  84.050003  22.933332
# 2018-11-15  31.622419   0.020  50.158714  57.456669  86.739998  23.229334
# 2018-11-16  31.101278   0.040  40.751015  56.536667  85.059998  23.620667
# 2018-11-19  29.370699   0.030  35.861279  54.480000  80.129997  23.564667
# 2018-11-20  28.515242   0.030  36.946789  55.250000  77.760002  23.166000
# 2018-11-21  28.908554   0.035  35.863766  55.646667  79.120003  22.546000
# 2018-11-22        NaN   0.030        NaN        NaN        NaN        NaN
#
#             UBER
# Date
# 2018-11-09   NaN
# 2018-11-12   NaN
# 2018-11-13   NaN
# 2018-11-14   NaN
# 2018-11-15   NaN
# 2018-11-16   NaN
# 2018-11-19   NaN
# 2018-11-20   NaN
# 2018-11-21   NaN
# 2018-11-22   NaN

# %%
prices[prices.index >= "2013-01-01"].plot(figsize=(15,10));

# %%
sample_cov = risk_models.sample_cov(prices, frequency=252)
sample_cov
# Out:
#              AAL      BIDU       DHR       DIS        FI     FWONK    MCL.CN  \
# AAL     0.250227  0.057087  0.025573  0.060222  0.043076  0.053309 -0.010132
# BIDU    0.057087  0.195300  0.029802  0.036759  0.034252  0.039791  0.006037
# DHR     0.025573  0.029802  0.051621  0.023267  0.027595  0.025616  0.004995
# DIS     0.060222  0.036759  0.023267  0.072503  0.035141  0.039715  0.005935
# FI      0.043076  0.034252  0.027595  0.035141  0.061493  0.036867 -0.004711
# FWONK   0.053309  0.039791  0.025616  0.039715  0.036867  0.118729 -0.001089
# MCL.CN -0.010132  0.006037  0.004995  0.005935 -0.004711 -0.001089  3.540795
# NVDA    0.067432  0.074736  0.046179  0.046366  0.047722  0.054630  0.000164
# PANW    0.047128  0.049476  0.031601  0.036554  0.032016  0.040064 -0.015128
# PYPL    0.055542  0.067547  0.043053  0.047917  0.051707  0.045212  0.005863
# TSLA    0.070934  0.082243  0.037853  0.044243  0.043413  0.051202  0.009588
# UBER    0.136926  0.114976  0.049618  0.089685  0.075079  0.086775  0.028691
#
#             NVDA      PANW      PYPL      TSLA      UBER
# AAL     0.067432  0.047128  0.055542  0.070934  0.136926
# BIDU    0.074736  0.049476  0.067547  0.082243  0.114976
# DHR     0.046179  0.031601  0.043053  0.037853  0.049618
# DIS     0.046366  0.036554  0.047917  0.044243  0.089685
# FI      0.047722  0.032016  0.051707  0.043413  0.075079
# FWONK   0.054630  0.040064  0.045212  0.051202  0.086775
# MCL.CN  0.000164 -0.015128  0.005863  0.009588  0.028691
# NVDA    0.210873  0.071736  0.095837  0.105854  0.136557
# PANW    0.071736  0.147456  0.062926  0.075641  0.090567
# PYPL    0.095837  0.062926  0.146409  0.088928  0.117968
# TSLA    0.105854  0.075641  0.088928  0.308686  0.154572
# UBER    0.136557  0.090567  0.117968  0.154572  0.316362

# %%
plotting.plot_covariance(sample_cov, plot_correlation=True);

# %%
mu = expected_returns.capm_return(prices)
mu
# Out:
# AAL       0.303388
# BIDU      0.283013
# DHR       0.153306
# DIS       0.195547
# FI        0.178347
# FWONK     0.218337
# MCL.CN    1.415292
# NVDA      0.338032
# PANW      0.246545
# PYPL      0.301390
# TSLA      0.377731
# UBER      0.517854
# Name: mkt, dtype: float64

# %%
ef = EfficientFrontier(mu,sample_cov)
weights = ef.max_sharpe() #for maximizing the Sharpe ratio #Optimization
cleaned_weights = ef.clean_weights() #to clean the raw weights
# Get the Keys and store them in a list
labels = list(cleaned_weights.keys())
# Get the Values and store them in a list
values = list(cleaned_weights.values())
fig, ax = plt.subplots()
ax.pie(values, labels=labels, autopct='%1.0f%%')
print('Portfolio Allocation')
plt.show(fig)
# Out:
# Portfolio Allocation

# %%
cleaned_weights
# Out:
# OrderedDict([('AAL', 0.07584),
#              ('BIDU', 0.0739),
#              ('DHR', 0.09983),
#              ('DIS', 0.02918),
#              ('FI', 0.0473),
#              ('FWONK', 0.08742),
#              ('MCL.CN', 0.10138),
#              ('NVDA', 0.06856),
#              ('PANW', 0.09167),
#              ('PYPL', 0.09876),
#              ('TSLA', 0.07254),
#              ('UBER', 0.15362)])

# %%
latest_prices = prices.loc[portfolio_creation_date]  # prices as of the day you are allocating
da = DiscreteAllocation(weights, latest_prices, total_portfolio_value=100000)
alloc, leftover = da.lp_portfolio(verbose=True)
print(f"Discrete allocation performed with ${leftover:.2f} leftover")
alloc
# Out:
# Funds remaining: 127.44
# AAL: allocated 0.076, desired 0.076
# BIDU: allocated 0.074, desired 0.074
# DHR: allocated 0.100, desired 0.100
# DIS: allocated 0.029, desired 0.029
# FI: allocated 0.047, desired 0.047
# FWONK: allocated 0.088, desired 0.087
# MCL.CN: allocated 0.102, desired 0.101
# NVDA: allocated 0.069, desired 0.069
# PANW: allocated 0.092, desired 0.092
# PYPL: allocated 0.098, desired 0.099
# TSLA: allocated 0.073, desired 0.073
# UBER: allocated 0.154, desired 0.154
# Allocation has RMSE: 0.000
# Discrete allocation performed with $127.44 leftover
# C:\Users\DOUGHJ-WS1\anaconda3\Lib\site-packages\cvxpy\problems\problem.py:1403: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# {'AAL': 225,
#  'BIDU': 47,
#  'DHR': 87,
#  'DIS': 22,
#  'FI': 55,
#  'FWONK': 231,
#  'MCL.CN': 289644,
#  'NVDA': 164,
#  'PANW': 117,
#  'PYPL': 89,
#  'TSLA': 454,
#  'UBER': 370}

# %%
ef.portfolio_performance(verbose=True);
# Out:
# Expected annual return: 41.8%
# Annual volatility: 32.2%
# Sharpe Ratio: 1.24

# %%
alloc_df = pd.DataFrame()
alloc_df = alloc_df.append(alloc,ignore_index=True)
alloc_df
# Out:
# C:\Users\DOUGHJ-WS1\AppData\Local\Temp\ipykernel_11400\1450910952.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   alloc_df = alloc_df.append(alloc,ignore_index=True)
#    AAL  BIDU  DHR  DIS  FI  FWONK  MCL.CN  NVDA  PANW  PYPL  TSLA  UBER
# 0  225    47   87   22  55    231  289644   164   117    89   454   370

# %%
current_values = prices.loc[portfolio_rebalance_date] * alloc_df
current_values
# Out:
#        AAL       BIDU       DHR          DIS          FI         FWONK  \
# 0  2643.75  5076.4701  17247.75  1860.979919  6556.54995  14830.199295
#
#          MCL.CN          NVDA          PANW         PYPL           TSLA  \
# 0  21723.300863  75366.197998  28323.360214  4862.070095  100869.716675
#
#            UBER
# 0  18470.399323

# %%
current_values_sum = current_values.sum(axis=1, numeric_only=True)
current_values_sum
# Out:
# 0    297830.744432
# dtype: float64

# %%
total_value = current_values_sum + leftover
total_value
# Out:
# 0    297958.185191
# dtype: float64
